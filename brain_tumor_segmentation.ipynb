# %%
# !pip install hdf5storage
# !git clone https://github.com/adityajn105/brain-tumor-segmentation-unet
# !bash tumor-segmentation-unet/download_data.sh
# !python tumor-segmentation-unet/mat_to_numpy.py brain_tumor_dataset/
# Out:
# Collecting hdf5storage
#   Downloading https://files.pythonhosted.org/packages/79/e0/5dd25068a231cd817265529368aca2f918049b290dcb2fd9b24ce136adf4/hdf5storage-0.1.15-py2.py3-none-any.whl (56kB)
#      |████████████████████████████████| 61kB 2.5MB/s
# Requirement already satisfied: h5py>=2.1; python_version >= "3.3" in /usr/local/lib/python3.6/dist-packages (from hdf5storage) (2.8.0)
# Requirement already satisfied: numpy; python_version >= "3.4" in /usr/local/lib/python3.6/dist-packages (from hdf5storage) (1.16.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py>=2.1; python_version >= "3.3"->hdf5storage) (1.12.0)
# Installing collected packages: hdf5storage
# Successfully installed hdf5storage-0.1.15
# Cloning into 'tumor-segmentation-unet'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 12 (delta 3), reused 6 (delta 1), pack-reused 0
# Unpacking objects: 100% (12/12), done.
# 3064
# [3064/3064] images loaded: 100.0 %tcmalloc: large alloc 1606418432 bytes == 0x93994000 @  0x7fec4949d1e7 0x7fec46fe6ca1 0x7fec4704b778 0x7fec4704eec0 0x7fec4704f435 0x7fec470e875d 0x4f8925 0x4f98c7 0x4f6128 0x4f9023 0x6415b2 0x64166a 0x643730 0x62b26e 0x4b4cb0 0x7fec4909ab97 0x5bdf6a
#
# labels: (3064,)
# images: (3064, 512, 512)
# masks: (3064, 512, 512)
# labels.npy, images.npy, masks.npy saved in brain_tumor_dataset/

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2

integer_to_class = {'1': 'meningioma (1)', '2': 'glioma (2)', '3': 'pituitary tumor (3)'}

##Load images, labels, masks
labels = np.load('brain_tumor_dataset/labels.npy')
images = np.clip( (np.load('brain_tumor_dataset/images.npy')/12728),0,1)
masks = np.load('brain_tumor_dataset/masks.npy')*1
print(labels.shape)
print(images.shape)
print(masks.shape)
# Out:
# (3064,)
# (3064, 512, 512)
# (3064, 512, 512)

# %%
from skimage.transform import resize
img_size_ori = 512
img_size_target = 128

images = np.expand_dims(images,axis=-1)
masks = np.expand_dims(masks,axis=-1)

def downsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_target, img_size_target), mode='constant', preserve_range=True,)
    
def upsample(img):
    if img_size_ori == img_size_target:
        return img
    return resize(img, (img_size_ori, img_size_ori), mode='constant', preserve_range=True)
  
images = np.array([ downsample(image) for image in images ])
masks = (np.array([ downsample(mask) for mask in masks ])>0)*1

print(images.shape)
print(masks.shape)
# Out:
# (3064, 128, 128, 1)
# (3064, 128, 128, 1)

# %%
classes, counts = np.unique(labels,return_counts=True)
plt.bar(classes,counts,tick_label=list(integer_to_class.values()))
print(counts)
# Out:
# [ 708 1426  930]

# %%
plt.figure(figsize=(12, 5))
for i, idx in enumerate(np.random.randint(images.shape[0], size=18), start=1):
    plt.subplot(3, 6, i)
    plt.imshow( np.squeeze(images[idx],axis=-1), cmap='gray')
    plt.imshow( np.squeeze(np.ones_like(masks[idx])-masks[idx],axis=-1), alpha=0.5, cmap='Set1')
    plt.title(integer_to_class[str(labels[idx])])
    plt.axis('off')

# %% [markdown]
# ### Train Image and its mask which is to be predicted

# %%
plt.figure(figsize=(12, 5))
i=1
for idx in np.random.randint( images.shape[0], size=9):
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(images[idx],axis=-1))
  plt.title("Train Image")
  plt.axis('off')
  plt.subplot(3,6,i);i+=1
  plt.imshow( np.squeeze(masks[idx],axis=-1)) 
  plt.title("Train Mask")
  plt.axis('off')

# %%
from sklearn.model_selection import train_test_split
import gc
X,X_v,Y,Y_v = train_test_split( images,masks,test_size=0.2,stratify=labels)
del images
del masks
del labels
gc.collect()
X.shape,X_v.shape
# Out:
# ((2451, 128, 128, 1), (613, 128, 128, 1))

# %% [markdown]
# ### Augmentation

# %%
X = np.append( X, [ np.fliplr(x) for x in X], axis=0 )
Y = np.append( Y, [ np.fliplr(y) for y in Y], axis=0 )
X.shape,Y.shape
# Out:
# ((4902, 128, 128, 1), (4902, 128, 128, 1))

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(brightness_range=(0.9,1.1),
                                   zoom_range=[.9,1.1],
                                   fill_mode='nearest')
val_datagen = ImageDataGenerator()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Defining Dice Loss
# Dice = 2|A∩B|/|A|+|B|

# %%
from keras.losses import binary_crossentropy
from keras import backend as K
import tensorflow as tf

def dice_loss(y_true, y_pred):
    smooth = 1.
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = y_true_f * y_pred_f
    score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
    return 1. - score

### bce_dice_loss = binary_crossentropy_loss + dice_loss
def bce_dice_loss(y_true, y_pred):
    return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# %%
from keras.layers import Conv2D, MaxPooling2D, Conv2DTranspose, concatenate, Dropout, Input, BatchNormalization
from keras import optimizers
from keras.models import Model

IMG_DIM = (128,128,1)

def conv2d_block( input_tensor, n_filters, kernel_size = (3,3), name="contraction"):
  "Add 2 conv layer"
  x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu", name=name+'_1')(input_tensor)
  
  x = Conv2D(filters=n_filters, kernel_size=kernel_size, kernel_initializer='he_normal', 
             padding='same',activation="relu",name=name+'_2')(x)
  return x
  

inp = Input( shape=IMG_DIM )

d1 = conv2d_block( inp, 64, name="contraction_1")
p1 = MaxPooling2D( pool_size=(2,2), strides=(2,2))(d1)
p1 = BatchNormalization(momentum=0.8)(p1)
p1 = Dropout(0.1)(p1)

d2 = conv2d_block( p1, 128, name="contraction_2_1" )
p2 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d2)
p2 = BatchNormalization(momentum=0.8)(p2)
p2 = Dropout(0.1)(p2)

d3 = conv2d_block( p2, 256, name="contraction_3_1")
p3 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d3)
p3 = BatchNormalization(momentum=0.8)(p3)
p3 = Dropout(0.1)(p3)

d4 = conv2d_block(p3,512, name="contraction_4_1")
p4 = MaxPooling2D(pool_size=(2,2), strides=(2,2) )(d4)
p4 = BatchNormalization(momentum=0.8)(p4)
p4 = Dropout(0.1)(p4)

d5 = conv2d_block(p4,512, name="contraction_5_1")

u1 = Conv2DTranspose(512, (3, 3), strides = (2, 2), padding = 'same')(d5)
u1 = concatenate([u1,d4])
u1 = Dropout(0.1)(u1)
c1 = conv2d_block(u1, 512, name="expansion_1")

u2 = Conv2DTranspose(256, (3, 3), strides = (2, 2), padding = 'same')(c1)
u2 = concatenate([u2,d3])
u2 = Dropout(0.1)(u2)
c2 = conv2d_block(u2, 256, name="expansion_2")

u3 = Conv2DTranspose(128, (3, 3), strides = (2, 2), padding = 'same')(c2)
u3 = concatenate([u3,d2])
u3 = Dropout(0.1)(u3)
c3 = conv2d_block(u3, 128, name="expansion_3")

u4 = Conv2DTranspose(64, (3, 3), strides = (2, 2), padding = 'same')(c3)
u4 = concatenate([u4,d1])
u4 = Dropout(0.1)(u4)
c4 = conv2d_block(u4,64, name="expansion_4")

out = Conv2D(1, (1,1), name="output", activation='sigmoid')(c4)

unet = Model( inp, out )
unet.summary()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0831 17:20:58.573488 140692205823872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0831 17:20:58.587826 140692205823872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0831 17:20:58.591181 140692205823872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4479: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# W0831 17:20:58.621183 140692205823872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0831 17:20:58.638451 140692205823872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0831 17:20:58.639831 140692205823872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0831 17:20:59.164346 140692205823872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:2041: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# W0831 17:20:59.242445 140692205823872 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# contraction_1_1 (Conv2D)        (None, 128, 128, 64) 640         input_1[0][0]
# __________________________________________________________________________________________________
# contraction_1_2 (Conv2D)        (None, 128, 128, 64) 36928       contraction_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)   0           contraction_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64, 64, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# contraction_2_1_1 (Conv2D)      (None, 64, 64, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# contraction_2_1_2 (Conv2D)      (None, 64, 64, 128)  147584      contraction_2_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0           contraction_2_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 128)  512         max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 32, 32, 128)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# contraction_3_1_1 (Conv2D)      (None, 32, 32, 256)  295168      dropout_2[0][0]
# __________________________________________________________________________________________________
# contraction_3_1_2 (Conv2D)      (None, 32, 32, 256)  590080      contraction_3_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0           contraction_3_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 256)  1024        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# contraction_4_1_1 (Conv2D)      (None, 16, 16, 512)  1180160     dropout_3[0][0]
# __________________________________________________________________________________________________
# contraction_4_1_2 (Conv2D)      (None, 16, 16, 512)  2359808     contraction_4_1_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 8, 8, 512)    0           contraction_4_1_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 8, 8, 512)    2048        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 512)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# contraction_5_1_1 (Conv2D)      (None, 8, 8, 512)    2359808     dropout_4[0][0]
# __________________________________________________________________________________________________
# contraction_5_1_2 (Conv2D)      (None, 8, 8, 512)    2359808     contraction_5_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 512)  2359808     contraction_5_1_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 1024) 0           conv2d_transpose_1[0][0]
#                                                                  contraction_4_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 16, 16, 1024) 0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# expansion_1_1 (Conv2D)          (None, 16, 16, 512)  4719104     dropout_5[0][0]
# __________________________________________________________________________________________________
# expansion_1_2 (Conv2D)          (None, 16, 16, 512)  2359808     expansion_1_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 256)  1179904     expansion_1_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 512)  0           conv2d_transpose_2[0][0]
#                                                                  contraction_3_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 32, 32, 512)  0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# expansion_2_1 (Conv2D)          (None, 32, 32, 256)  1179904     dropout_6[0][0]
# __________________________________________________________________________________________________
# expansion_2_2 (Conv2D)          (None, 32, 32, 256)  590080      expansion_2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 128)  295040      expansion_2_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 256)  0           conv2d_transpose_3[0][0]
#                                                                  contraction_2_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64, 64, 256)  0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# expansion_3_1 (Conv2D)          (None, 64, 64, 128)  295040      dropout_7[0][0]
# __________________________________________________________________________________________________
# expansion_3_2 (Conv2D)          (None, 64, 64, 128)  147584      expansion_3_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 64) 73792       expansion_3_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 128 0           conv2d_transpose_4[0][0]
#                                                                  contraction_1_2[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128, 128, 128 0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# expansion_4_1 (Conv2D)          (None, 128, 128, 64) 73792       dropout_8[0][0]
# __________________________________________________________________________________________________
# expansion_4_2 (Conv2D)          (None, 128, 128, 64) 36928       expansion_4_1[0][0]
# __________________________________________________________________________________________________
# output (Conv2D)                 (None, 128, 128, 1)  65          expansion_4_2[0][0]
# ==================================================================================================
# Total params: 22,718,529
# Trainable params: 22,716,609
# Non-trainable params: 1,920
# __________________________________________________________________________________________________

# %% [markdown]
# ### Defining IOU metric and compile Model

# %%
def get_iou_vector(A, B):
    t = A>0
    p = B>0
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou

def iou_metric(label, pred):
    return tf.py_func(get_iou_vector, [label, pred>0.5], tf.float64)

unet.compile(optimizer=optimizers.Adam(lr=1e-3), 
             loss=bce_dice_loss, metrics=['accuracy',iou_metric])
# Out:
# W0831 17:21:00.035040 140692205823872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0831 17:21:00.046445 140692205823872 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# W0831 17:21:00.085378 140692205823872 deprecation.py:323] From <ipython-input-11-0b86264e04b1>:10: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder
from keras.models import load_model

model_checkpoint  = ModelCheckpoint('model_best_checkpoint.h5', save_best_only=True, 
                                    monitor='val_loss', mode='min', verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, mode='min')
reduceLR = ReduceLROnPlateau(patience=4, verbose=2, monitor='val_loss',min_lr=1e-4, mode='min')

callback_list = [early_stopping, reduceLR, model_checkpoint]

train_generator = train_datagen.flow(X, Y, batch_size=32)
val_generator = val_datagen.flow(X_v, Y_v, batch_size=32)

hist = unet.fit(X,Y,batch_size=32,epochs=100,
               validation_data=(X_v,Y_v),verbose=1,callbacks= callback_list)

unet = load_model('model_best_checkpoint.h5', custom_objects={'bce_dice_loss': bce_dice_loss,'iou_metric':iou_metric}) #or compile = False
# Out:
# Train on 4902 samples, validate on 613 samples
# Epoch 1/50
# 4902/4902 [==============================] - 165s 34ms/step - loss: 0.9205 - acc: 0.9823 - iou_metric: 0.0728 - val_loss: 0.7942 - val_acc: 0.9864 - val_iou_metric: 0.1711
#
# Epoch 00001: val_loss improved from inf to 0.79421, saving model to model_best_checkpoint.h5
# Epoch 2/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.6988 - acc: 0.9851 - iou_metric: 0.2442 - val_loss: 0.7585 - val_acc: 0.9741 - val_iou_metric: 0.2169
#
# Epoch 00002: val_loss improved from 0.79421 to 0.75848, saving model to model_best_checkpoint.h5
# Epoch 3/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.5470 - acc: 0.9892 - iou_metric: 0.3548 - val_loss: 0.4638 - val_acc: 0.9925 - val_iou_metric: 0.4162
#
# Epoch 00003: val_loss improved from 0.75848 to 0.46377, saving model to model_best_checkpoint.h5
# Epoch 4/50
# 4902/4902 [==============================] - 159s 33ms/step - loss: 0.4379 - acc: 0.9917 - iou_metric: 0.4464 - val_loss: 0.4267 - val_acc: 0.9924 - val_iou_metric: 0.4544
#
# Epoch 00004: val_loss improved from 0.46377 to 0.42668, saving model to model_best_checkpoint.h5
# Epoch 5/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.3776 - acc: 0.9929 - iou_metric: 0.5049 - val_loss: 0.4316 - val_acc: 0.9935 - val_iou_metric: 0.4502
#
# Epoch 00005: val_loss did not improve from 0.42668
# Epoch 6/50
# 4902/4902 [==============================] - 159s 33ms/step - loss: 0.3539 - acc: 0.9934 - iou_metric: 0.5289 - val_loss: 0.4361 - val_acc: 0.9905 - val_iou_metric: 0.4522
#
# Epoch 00006: val_loss did not improve from 0.42668
# Epoch 7/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.3303 - acc: 0.9938 - iou_metric: 0.5554 - val_loss: 0.3578 - val_acc: 0.9940 - val_iou_metric: 0.5203
#
# Epoch 00007: val_loss improved from 0.42668 to 0.35779, saving model to model_best_checkpoint.h5
# Epoch 8/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.3111 - acc: 0.9941 - iou_metric: 0.5740 - val_loss: 0.3453 - val_acc: 0.9940 - val_iou_metric: 0.5383
#
# Epoch 00008: val_loss improved from 0.35779 to 0.34534, saving model to model_best_checkpoint.h5
# Epoch 9/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2855 - acc: 0.9946 - iou_metric: 0.6012 - val_loss: 0.3423 - val_acc: 0.9947 - val_iou_metric: 0.5404
#
# Epoch 00009: val_loss improved from 0.34534 to 0.34230, saving model to model_best_checkpoint.h5
# Epoch 10/50
# 4902/4902 [==============================] - 159s 33ms/step - loss: 0.2710 - acc: 0.9949 - iou_metric: 0.6177 - val_loss: 0.4075 - val_acc: 0.9940 - val_iou_metric: 0.4727
#
# Epoch 00010: val_loss did not improve from 0.34230
# Epoch 11/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2747 - acc: 0.9948 - iou_metric: 0.6142 - val_loss: 0.3381 - val_acc: 0.9938 - val_iou_metric: 0.5405
#
# Epoch 00011: val_loss improved from 0.34230 to 0.33810, saving model to model_best_checkpoint.h5
# Epoch 12/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2505 - acc: 0.9953 - iou_metric: 0.6415 - val_loss: 0.3104 - val_acc: 0.9947 - val_iou_metric: 0.5698
#
# Epoch 00012: val_loss improved from 0.33810 to 0.31040, saving model to model_best_checkpoint.h5
# Epoch 13/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2466 - acc: 0.9953 - iou_metric: 0.6458 - val_loss: 0.3044 - val_acc: 0.9947 - val_iou_metric: 0.5773
#
# Epoch 00013: val_loss improved from 0.31040 to 0.30443, saving model to model_best_checkpoint.h5
# Epoch 14/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2268 - acc: 0.9957 - iou_metric: 0.6695 - val_loss: 0.3018 - val_acc: 0.9945 - val_iou_metric: 0.5811
#
# Epoch 00014: val_loss improved from 0.30443 to 0.30179, saving model to model_best_checkpoint.h5
# Epoch 15/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2297 - acc: 0.9956 - iou_metric: 0.6665 - val_loss: 0.2900 - val_acc: 0.9948 - val_iou_metric: 0.5939
#
# Epoch 00015: val_loss improved from 0.30179 to 0.29001, saving model to model_best_checkpoint.h5
# Epoch 16/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2250 - acc: 0.9957 - iou_metric: 0.6722 - val_loss: 0.2930 - val_acc: 0.9948 - val_iou_metric: 0.5906
#
# Epoch 00016: val_loss did not improve from 0.29001
# Epoch 17/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2234 - acc: 0.9958 - iou_metric: 0.6743 - val_loss: 0.3699 - val_acc: 0.9936 - val_iou_metric: 0.5132
#
# Epoch 00017: val_loss did not improve from 0.29001
# Epoch 18/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2207 - acc: 0.9958 - iou_metric: 0.6773 - val_loss: 0.2963 - val_acc: 0.9950 - val_iou_metric: 0.5850
#
# Epoch 00018: val_loss did not improve from 0.29001
# Epoch 19/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.2006 - acc: 0.9962 - iou_metric: 0.7025 - val_loss: 0.2940 - val_acc: 0.9945 - val_iou_metric: 0.5928
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00019: val_loss did not improve from 0.29001
# Epoch 20/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1758 - acc: 0.9966 - iou_metric: 0.7334 - val_loss: 0.2601 - val_acc: 0.9955 - val_iou_metric: 0.6280
#
# Epoch 00020: val_loss improved from 0.29001 to 0.26012, saving model to model_best_checkpoint.h5
# Epoch 21/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1645 - acc: 0.9968 - iou_metric: 0.7479 - val_loss: 0.2572 - val_acc: 0.9955 - val_iou_metric: 0.6309
#
# Epoch 00021: val_loss improved from 0.26012 to 0.25723, saving model to model_best_checkpoint.h5
# Epoch 22/50
# 4902/4902 [==============================] - 156s 32ms/step - loss: 0.1618 - acc: 0.9969 - iou_metric: 0.7520 - val_loss: 0.2551 - val_acc: 0.9956 - val_iou_metric: 0.6330
#
# Epoch 00022: val_loss improved from 0.25723 to 0.25507, saving model to model_best_checkpoint.h5
# Epoch 23/50
# 4902/4902 [==============================] - 157s 32ms/step - loss: 0.1584 - acc: 0.9970 - iou_metric: 0.7565 - val_loss: 0.2526 - val_acc: 0.9955 - val_iou_metric: 0.6363
#
# Epoch 00023: val_loss improved from 0.25507 to 0.25263, saving model to model_best_checkpoint.h5
# Epoch 24/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1537 - acc: 0.9971 - iou_metric: 0.7630 - val_loss: 0.2519 - val_acc: 0.9956 - val_iou_metric: 0.6373
#
# Epoch 00024: val_loss improved from 0.25263 to 0.25185, saving model to model_best_checkpoint.h5
# Epoch 25/50
# 4896/4902 [============================>.] - ETA: 0s - loss: 0.1529 - acc: 0.9971 - iou_metric: 0.7638
# Epoch 00025: val_loss did not improve from 0.25185
# Epoch 26/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1499 - acc: 0.9971 - iou_metric: 0.7684 - val_loss: 0.2500 - val_acc: 0.9957 - val_iou_metric: 0.6399
#
# Epoch 00026: val_loss improved from 0.25185 to 0.25004, saving model to model_best_checkpoint.h5
# Epoch 27/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1481 - acc: 0.9972 - iou_metric: 0.7706 - val_loss: 0.2506 - val_acc: 0.9957 - val_iou_metric: 0.6390
#
# Epoch 00027: val_loss did not improve from 0.25004
# Epoch 28/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1465 - acc: 0.9972 - iou_metric: 0.7727 - val_loss: 0.2479 - val_acc: 0.9957 - val_iou_metric: 0.6423
#
# Epoch 00028: val_loss improved from 0.25004 to 0.24791, saving model to model_best_checkpoint.h5
# Epoch 29/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1434 - acc: 0.9972 - iou_metric: 0.7773 - val_loss: 0.2496 - val_acc: 0.9956 - val_iou_metric: 0.6399
#
# Epoch 00029: val_loss did not improve from 0.24791
# Epoch 30/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1418 - acc: 0.9973 - iou_metric: 0.7798 - val_loss: 0.2465 - val_acc: 0.9957 - val_iou_metric: 0.6440
#
# Epoch 00030: val_loss improved from 0.24791 to 0.24645, saving model to model_best_checkpoint.h5
# Epoch 31/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1385 - acc: 0.9973 - iou_metric: 0.7843 - val_loss: 0.2482 - val_acc: 0.9957 - val_iou_metric: 0.6419
#
# Epoch 00031: val_loss did not improve from 0.24645
# Epoch 32/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1366 - acc: 0.9974 - iou_metric: 0.7870 - val_loss: 0.2462 - val_acc: 0.9957 - val_iou_metric: 0.6440
#
# Epoch 00032: val_loss improved from 0.24645 to 0.24620, saving model to model_best_checkpoint.h5
# Epoch 33/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1350 - acc: 0.9974 - iou_metric: 0.7889 - val_loss: 0.2473 - val_acc: 0.9958 - val_iou_metric: 0.6421
#
# Epoch 00033: val_loss did not improve from 0.24620
# Epoch 34/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1331 - acc: 0.9975 - iou_metric: 0.7919 - val_loss: 0.2478 - val_acc: 0.9958 - val_iou_metric: 0.6431
#
# Epoch 00034: val_loss did not improve from 0.24620
# Epoch 35/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1333 - acc: 0.9975 - iou_metric: 0.7914 - val_loss: 0.2494 - val_acc: 0.9957 - val_iou_metric: 0.6410
#
# Epoch 00035: val_loss did not improve from 0.24620
# Epoch 36/50
# 4902/4902 [==============================] - 158s 32ms/step - loss: 0.1303 - acc: 0.9975 - iou_metric: 0.7957 - val_loss: 0.2453 - val_acc: 0.9958 - val_iou_metric: 0.6448
#
# Epoch 00036: val_loss improved from 0.24620 to 0.24532, saving model to model_best_checkpoint.h5
# Epoch 37/50
# 4902/4902 [==============================] - 157s 32ms/step - loss: 0.1277 - acc: 0.9975 - iou_metric: 0.7994 - val_loss: 0.2437 - val_acc: 0.9957 - val_iou_metric: 0.6475
#
# Epoch 00037: val_loss improved from 0.24532 to 0.24370, saving model to model_best_checkpoint.h5
# Epoch 38/50
# 4902/4902 [==============================] - 159s 33ms/step - loss: 0.1263 - acc: 0.9976 - iou_metric: 0.8014 - val_loss: 0.2447 - val_acc: 0.9958 - val_iou_metric: 0.6470
#
# Epoch 00038: val_loss did not improve from 0.24370
# Epoch 39/50
# 4902/4902 [==============================] - 159s 33ms/step - loss: 0.1241 - acc: 0.9976 - iou_metric: 0.8046 - val_loss: 0.2486 - val_acc: 0.9956 - val_iou_metric: 0.6410
#
# Epoch 00039: val_loss did not improve from 0.24370
# Epoch 40/50
# 4902/4902 [==============================] - 160s 33ms/step - loss: 0.1221 - acc: 0.9977 - iou_metric: 0.8074 - val_loss: 0.2438 - val_acc: 0.9957 - val_iou_metric: 0.6477
#
# Epoch 00040: val_loss did not improve from 0.24370
# Epoch 41/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.1225 - acc: 0.9977 - iou_metric: 0.8069 - val_loss: 0.2453 - val_acc: 0.9958 - val_iou_metric: 0.6459
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00041: val_loss did not improve from 0.24370
# Epoch 42/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.1188 - acc: 0.9977 - iou_metric: 0.8122 - val_loss: 0.2462 - val_acc: 0.9957 - val_iou_metric: 0.6451
#
# Epoch 00042: val_loss did not improve from 0.24370
# Epoch 43/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.1183 - acc: 0.9977 - iou_metric: 0.8130 - val_loss: 0.2449 - val_acc: 0.9957 - val_iou_metric: 0.6457
#
# Epoch 00043: val_loss did not improve from 0.24370
# Epoch 44/50
# 4902/4902 [==============================] - 159s 33ms/step - loss: 0.1148 - acc: 0.9978 - iou_metric: 0.8178 - val_loss: 0.2436 - val_acc: 0.9957 - val_iou_metric: 0.6469
#
# Epoch 00044: val_loss improved from 0.24370 to 0.24364, saving model to model_best_checkpoint.h5
# Epoch 45/50
# 4902/4902 [==============================] - 160s 33ms/step - loss: 0.1132 - acc: 0.9978 - iou_metric: 0.8203 - val_loss: 0.2454 - val_acc: 0.9958 - val_iou_metric: 0.6451
#
# Epoch 00045: val_loss did not improve from 0.24364
# Epoch 46/50
# 4902/4902 [==============================] - 159s 33ms/step - loss: 0.1119 - acc: 0.9979 - iou_metric: 0.8223 - val_loss: 0.2470 - val_acc: 0.9957 - val_iou_metric: 0.6447
#
# Epoch 00046: val_loss did not improve from 0.24364
# Epoch 47/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.1105 - acc: 0.9979 - iou_metric: 0.8245 - val_loss: 0.2407 - val_acc: 0.9957 - val_iou_metric: 0.6514
#
# Epoch 00047: val_loss improved from 0.24364 to 0.24072, saving model to model_best_checkpoint.h5
# Epoch 48/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.1088 - acc: 0.9979 - iou_metric: 0.8268 - val_loss: 0.2405 - val_acc: 0.9958 - val_iou_metric: 0.6520
#
# Epoch 00048: val_loss improved from 0.24072 to 0.24053, saving model to model_best_checkpoint.h5
# Epoch 49/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.1066 - acc: 0.9980 - iou_metric: 0.8298 - val_loss: 0.2417 - val_acc: 0.9958 - val_iou_metric: 0.6508
#
# Epoch 00049: val_loss did not improve from 0.24053
# Epoch 50/50
# 4902/4902 [==============================] - 159s 32ms/step - loss: 0.1054 - acc: 0.9980 - iou_metric: 0.8318 - val_loss: 0.2430 - val_acc: 0.9958 - val_iou_metric: 0.6490
#
# Epoch 00050: val_loss did not improve from 0.24053

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(16, 4))
t = f.suptitle('Unet Performance in Segmenting Tumors', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
epoch_list = hist.epoch

ax1.plot(epoch_list, hist.history['acc'], label='Train Accuracy')
ax1.plot(epoch_list, hist.history['val_acc'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, epoch_list[-1], 5))
ax1.set_ylabel('Accuracy Value');ax1.set_xlabel('Epoch');ax1.set_title('Accuracy')
ax1.legend(loc="best");ax1.grid(color='gray', linestyle='-', linewidth=0.5)

ax2.plot(epoch_list, hist.history['loss'], label='Train Loss')
ax2.plot(epoch_list, hist.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, epoch_list[-1], 5))
ax2.set_ylabel('Loss Value');ax2.set_xlabel('Epoch');ax2.set_title('Loss')
ax2.legend(loc="best");ax2.grid(color='gray', linestyle='-', linewidth=0.5)

ax3.plot(epoch_list, hist.history['iou_metric'], label='Train IOU metric')
ax3.plot(epoch_list, hist.history['val_iou_metric'], label='Validation IOU metric')
ax3.set_xticks(np.arange(0, epoch_list[-1], 5))
ax3.set_ylabel('IOU metric');ax3.set_xlabel('Epoch');ax3.set_title('IOU metric')
ax3.legend(loc="best");ax3.grid(color='gray', linestyle='-', linewidth=0.5)

# %%
# src: https://www.kaggle.com/aglotero/another-iou-metric
def get_iou_vector(A, B):
    t = A>0
    p = B>0
    intersection = np.logical_and(t,p)
    union = np.logical_or(t,p)
    iou = (np.sum(intersection) + 1e-10 )/ (np.sum(union) + 1e-10)
    return iou
  
def getIOUCurve(mask_org,predicted):
  thresholds = np.linspace(0, 1, 100)
  ious = np.array([get_iou_vector(mask_org, predicted > threshold) for threshold in thresholds])
  thres_best_index = np.argmax(ious[9:-10]) + 9
  iou_best = ious[thres_best_index]
  thres_best = thresholds[thres_best_index]
  return thresholds,ious,iou_best,thres_best

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Unet Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

th, ious, iou_best, th_best = getIOUCurve(Y_v,unet.predict(X_v))
ax1.plot(th, ious,label="For Validation")
ax1.plot(th_best, iou_best, "xr", label="Best threshold")
ax1.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax1.set_title("Threshold vs IoU ({}, {})".format(th_best, iou_best))

th, ious, iou_best, th_best = getIOUCurve(Y,unet.predict(X))
ax2.plot(th, ious, label="For Training")
ax2.plot(th_best, iou_best, "xr", label="Best threshold")
ax2.set_ylabel('IOU');ax1.set_xlabel('Threshold')
ax2.set_title("Threshold vs IoU ({}, {})".format(th_best, iou_best))
# Out:
# Text(0.5, 1.0, 'Threshold vs IoU (0.43434343434343436, 0.8470130609077978)')

# %%
THRESHOLD = 0.2
predicted_mask = (unet.predict(X_v)>THRESHOLD)*1

plt.figure(figsize=(8,30))
i=1;total=10
temp = np.ones_like( Y_v[0] )
for idx in np.random.randint(0,high=X_v.shape[0],size=total):
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.title("MRI Image");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - Y_v[idx],axis=-1), alpha=0.2, cmap='Set1' )
    plt.title("Original Mask");plt.axis('off')
    
    plt.subplot(total,3,i);i+=1
    plt.imshow( np.squeeze(X_v[idx],axis=-1), cmap='gray' )
    plt.imshow( np.squeeze(temp - predicted_mask[idx],axis=-1),  alpha=0.2, cmap='Set1' )
    plt.title("Predicted Mask");plt.axis('off')
